# %%
import mne
# Out:
# /Users/siddharth/opt/anaconda3/lib/python3.9/site-packages/mne/fixes.py:988: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(numba.__version__) < LooseVersion('0.40'):
# /Users/siddharth/opt/anaconda3/lib/python3.9/site-packages/mne/fixes.py:988: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(numba.__version__) < LooseVersion('0.40'):

# %%
def read_data(path):
  raw=mne.io.read_raw_gdf(path,preload=True,
                          eog=['EOG-left', 'EOG-central', 'EOG-right'])
  raw.drop_channels(['EOG-left', 'EOG-central', 'EOG-right'])
  raw.set_eeg_reference()
  events=mne.events_from_annotations(raw)
  epochs = mne.Epochs(raw, events[0], event_id=[7,8,9,10],on_missing ='warn')
  labels=epochs.events[:,-1]
  features=epochs.get_data()
  return features,labels

# %%
features,labels,groups=[],[],[]
for i in range(1,10):
  feature,label=read_data(f'/Users/siddharth/Downloads/BCICIV_2a_gdf/A0{i}T.gdf')
  features.append(feature)
  labels.append(label)
  groups.append([i]*len(label))
# Out:
# Extracting EDF parameters from /Users/siddharth/Downloads/BCICIV_2a_gdf/A01T.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 672527  =      0.000 ...  2690.108 secs...
# /Users/siddharth/opt/anaconda3/lib/python3.9/site-packages/mne/io/edf/edf.py:1044: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, UINT8).tolist()[0]
# /var/folders/dh/nfwywq5x6vj6wb3fkdkwkg000000gn/T/ipykernel_13072/3557320466.py:2: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   raw=mne.io.read_raw_gdf(path,preload=True,
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Used Annotations descriptions: ['1023', '1072', '276', '277', '32766', '768', '769', '770', '771', '772']
# Not setting metadata
# Not setting metadata
# 288 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 288 events and 176 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /Users/siddharth/Downloads/BCICIV_2a_gdf/A02T.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 677168  =      0.000 ...  2708.672 secs...
# /Users/siddharth/opt/anaconda3/lib/python3.9/site-packages/mne/io/edf/edf.py:1044: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, UINT8).tolist()[0]
# /var/folders/dh/nfwywq5x6vj6wb3fkdkwkg000000gn/T/ipykernel_13072/3557320466.py:2: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   raw=mne.io.read_raw_gdf(path,preload=True,
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Used Annotations descriptions: ['1023', '1072', '276', '277', '32766', '768', '769', '770', '771', '772']
# Not setting metadata
# Not setting metadata
# 288 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 288 events and 176 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /Users/siddharth/Downloads/BCICIV_2a_gdf/A03T.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 660529  =      0.000 ...  2642.116 secs...
# /Users/siddharth/opt/anaconda3/lib/python3.9/site-packages/mne/io/edf/edf.py:1044: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, UINT8).tolist()[0]
# /var/folders/dh/nfwywq5x6vj6wb3fkdkwkg000000gn/T/ipykernel_13072/3557320466.py:2: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   raw=mne.io.read_raw_gdf(path,preload=True,
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Used Annotations descriptions: ['1023', '1072', '276', '277', '32766', '768', '769', '770', '771', '772']
# Not setting metadata
# Not setting metadata
# 288 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 288 events and 176 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /Users/siddharth/Downloads/BCICIV_2a_gdf/A04T.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 600914  =      0.000 ...  2403.656 secs...
# /Users/siddharth/opt/anaconda3/lib/python3.9/site-packages/mne/io/edf/edf.py:1044: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, UINT8).tolist()[0]
# /var/folders/dh/nfwywq5x6vj6wb3fkdkwkg000000gn/T/ipykernel_13072/3557320466.py:2: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   raw=mne.io.read_raw_gdf(path,preload=True,
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Used Annotations descriptions: ['1023', '1072', '32766', '768', '769', '770', '771', '772']
# Not setting metadata
# Not setting metadata
# 144 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 144 events and 176 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /Users/siddharth/Downloads/BCICIV_2a_gdf/A05T.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 686119  =      0.000 ...  2744.476 secs...
# /var/folders/dh/nfwywq5x6vj6wb3fkdkwkg000000gn/T/ipykernel_13072/3557320466.py:7: RuntimeWarning: No matching events found for 9 (event id 9)
#   epochs = mne.Epochs(raw, events[0], event_id=[7,8,9,10],on_missing ='warn')
# /var/folders/dh/nfwywq5x6vj6wb3fkdkwkg000000gn/T/ipykernel_13072/3557320466.py:7: RuntimeWarning: No matching events found for 10 (event id 10)
#   epochs = mne.Epochs(raw, events[0], event_id=[7,8,9,10],on_missing ='warn')
# /Users/siddharth/opt/anaconda3/lib/python3.9/site-packages/mne/io/edf/edf.py:1044: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, UINT8).tolist()[0]
# /var/folders/dh/nfwywq5x6vj6wb3fkdkwkg000000gn/T/ipykernel_13072/3557320466.py:2: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   raw=mne.io.read_raw_gdf(path,preload=True,
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Used Annotations descriptions: ['1023', '1072', '276', '277', '32766', '768', '769', '770', '771', '772']
# Not setting metadata
# Not setting metadata
# 288 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 288 events and 176 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /Users/siddharth/Downloads/BCICIV_2a_gdf/A06T.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 678979  =      0.000 ...  2715.916 secs...
# /Users/siddharth/opt/anaconda3/lib/python3.9/site-packages/mne/io/edf/edf.py:1044: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, UINT8).tolist()[0]
# /var/folders/dh/nfwywq5x6vj6wb3fkdkwkg000000gn/T/ipykernel_13072/3557320466.py:2: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   raw=mne.io.read_raw_gdf(path,preload=True,
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Used Annotations descriptions: ['1023', '1072', '276', '277', '32766', '768', '769', '770', '771', '772']
# Not setting metadata
# Not setting metadata
# 288 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 288 events and 176 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /Users/siddharth/Downloads/BCICIV_2a_gdf/A07T.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 681070  =      0.000 ...  2724.280 secs...
# /Users/siddharth/opt/anaconda3/lib/python3.9/site-packages/mne/io/edf/edf.py:1044: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, UINT8).tolist()[0]
# /var/folders/dh/nfwywq5x6vj6wb3fkdkwkg000000gn/T/ipykernel_13072/3557320466.py:2: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   raw=mne.io.read_raw_gdf(path,preload=True,
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Used Annotations descriptions: ['1023', '1072', '276', '277', '32766', '768', '769', '770', '771', '772']
# Not setting metadata
# Not setting metadata
# 288 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 288 events and 176 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /Users/siddharth/Downloads/BCICIV_2a_gdf/A08T.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 675269  =      0.000 ...  2701.076 secs...
# /Users/siddharth/opt/anaconda3/lib/python3.9/site-packages/mne/io/edf/edf.py:1044: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, UINT8).tolist()[0]
# /var/folders/dh/nfwywq5x6vj6wb3fkdkwkg000000gn/T/ipykernel_13072/3557320466.py:2: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   raw=mne.io.read_raw_gdf(path,preload=True,
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Used Annotations descriptions: ['1023', '1072', '276', '277', '32766', '768', '769', '770', '771', '772']
# Not setting metadata
# Not setting metadata
# 288 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 288 events and 176 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /Users/siddharth/Downloads/BCICIV_2a_gdf/A09T.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 673327  =      0.000 ...  2693.308 secs...
# /Users/siddharth/opt/anaconda3/lib/python3.9/site-packages/mne/io/edf/edf.py:1044: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, UINT8).tolist()[0]
# /var/folders/dh/nfwywq5x6vj6wb3fkdkwkg000000gn/T/ipykernel_13072/3557320466.py:2: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   raw=mne.io.read_raw_gdf(path,preload=True,
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Used Annotations descriptions: ['1023', '1072', '276', '277', '32766', '768', '769', '770', '771', '772']
# Not setting metadata
# Not setting metadata
# 288 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 288 events and 176 original time points ...
# 0 bad epochs dropped

# %%
labels=labels-7

# %%
import numpy as np
features=np.concatenate(features)
labels=np.concatenate(labels)
groups=np.concatenate(groups)

# %%
features=np.moveaxis(features,1,2)

# %%
print(features.shape,labels.shape,groups.shape)
# Out:
# (2448, 176, 22) (2448,) (2448,)

# %%
from tensorflow.keras.layers import Conv1D,BatchNormalization,LeakyReLU,MaxPool1D,\
GlobalAveragePooling1D,Dense,Dropout,AveragePooling1D
from tensorflow.keras.models import Sequential
from tensorflow.keras.backend import clear_session
from keras.optimizers import SGD
def cnnmodel():
    clear_session()
    model=Sequential()
    model.add(Conv1D(filters=5,kernel_size=3,strides=1,input_shape=(176,22)))#1
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(MaxPool1D(pool_size=2,strides=2))#2
    model.add(Conv1D(filters=5,kernel_size=3,strides=1))#3
    model.add(LeakyReLU())
    model.add(MaxPool1D(pool_size=2,strides=2))#4
    model.add(Dropout(0.5))
    model.add(Conv1D(filters=5,kernel_size=3,strides=1))#5
    model.add(LeakyReLU())
    model.add(AveragePooling1D(pool_size=2,strides=2))#6
    model.add(Dropout(0.5))
    model.add(Conv1D(filters=5,kernel_size=3,strides=1))#7
    model.add(LeakyReLU())
    model.add(AveragePooling1D(pool_size=2,strides=2))#8
    model.add(Conv1D(filters=5,kernel_size=3,strides=1))#9
    model.add(LeakyReLU())
    model.add(GlobalAveragePooling1D())#10
    model.add(Dense(1,activation='ReLU'))#11
    opt = SGD(lr=0.01, momentum=0.9)
    model.compile(loss='sparse_categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    return model

model=cnnmodel()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 174, 5)            335
#
#  batch_normalization (BatchN  (None, 174, 5)           20
#  ormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 174, 5)            0
#
#  max_pooling1d (MaxPooling1D  (None, 87, 5)            0
#  )
#
#  conv1d_1 (Conv1D)           (None, 85, 5)             80
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 85, 5)             0
#
#  max_pooling1d_1 (MaxPooling  (None, 42, 5)            0
#  1D)
#
#  dropout (Dropout)           (None, 42, 5)             0
#
#  conv1d_2 (Conv1D)           (None, 40, 5)             80
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 40, 5)             0
#
#  average_pooling1d (AverageP  (None, 20, 5)            0
#  ooling1D)
#
#  dropout_1 (Dropout)         (None, 20, 5)             0
#
#  conv1d_3 (Conv1D)           (None, 18, 5)             80
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 18, 5)             0
#
#  average_pooling1d_1 (Averag  (None, 9, 5)             0
#  ePooling1D)
#
#  conv1d_4 (Conv1D)           (None, 7, 5)              80
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 7, 5)              0
#
#  global_average_pooling1d (G  (None, 5)                0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 1)                 6
#
# =================================================================
# Total params: 681
# Trainable params: 671
# Non-trainable params: 10
# _________________________________________________________________

# %%
from sklearn.model_selection import GroupKFold,LeaveOneGroupOut
from sklearn.preprocessing import StandardScaler
gkf=GroupKFold()

# %%
accuracy=[]
for train_index, val_index in gkf.split(features, labels, groups=groups):
    train_features,train_labels=features[train_index],labels[train_index]
    val_features,val_labels=features[val_index],labels[val_index]
    scaler=StandardScaler()
    train_features = scaler.fit_transform(train_features.reshape(-1, train_features.shape[-1])).reshape(train_features.shape)
    val_features = scaler.transform(val_features.reshape(-1, val_features.shape[-1])).reshape(val_features.shape)
    model=cnnmodel()
    model.fit(train_features,train_labels,epochs=50,batch_size=128,validation_data=(val_features,val_labels))
    accuracy.append(model.evaluate(val_features,val_labels)[1])
# Out:
# Epoch 1/50
# /Users/siddharth/opt/anaconda3/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 2024-10-01 21:15:44.255551: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 15/15 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.2719
# 2024-10-01 21:15:47.507771: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 15/15 [==============================] - 5s 174ms/step - loss: 0.0000e+00 - accuracy: 0.2719 - val_loss: 0.0000e+00 - val_accuracy: 0.2500
# Epoch 2/50
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.2692 - val_loss: 0.0000e+00 - val_accuracy: 0.2500
# Epoch 3/50
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0000e+00 - accuracy: 0.2692 - val_loss: 0.0000e+00 - val_accuracy: 0.2500
# Epoch 4/50
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0000e+00 - accuracy: 0.2692 - val_loss: 0.0000e+00 - val_accuracy: 0.2500
# Epoch 5/50
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0000e+00 - accuracy: 0.2692 - val_loss: 0.0000e+00 - val_accuracy: 0.2500
# Epoch 6/50
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0000e+00 - accuracy: 0.2692 - val_loss: 0.0000e+00 - val_accuracy: 0.2500
# Epoch 7/50
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0000e+00 - accuracy: 0.2692 - val_loss: 0.0000e+00 - val_accuracy: 0.2500
# Epoch 8/50
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0000e+00 - accuracy: 0.2692 - val_loss: 0.0000e+00 - val_accuracy: 0.2500
# Epoch 9/50
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0000e+00 - accuracy: 0.2692 - val_loss: 0.0000e+00 - val_accuracy: 0.2500
# Epoch 10/50
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0000e+00 - accuracy: 0.2692 - val_loss: 0.0000e+00 - val_accuracy: 0.2500
# Epoch 11/50
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0000e+00 - accuracy: 0.2692 - val_loss: 0.0000e+00 - val_accuracy: 0.2500
# Epoch 12/50
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0000e+00 - accuracy: 0.2692 - val_loss: 0.0000e+00 - val_accuracy: 0.2500
# Epoch 13/50
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0000e+00 - accuracy: 0.2692 - val_loss: 0.0000e+00 - val_accuracy: 0.2500
# Epoch 14/50
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0000e+00 - accuracy: 0.2692 - val_loss: 0.0000e+00 - val_accuracy: 0.2500
# Epoch 15/50
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0000e+00 - accuracy: 0.2692 - val_loss: 0.0000e+00 - val_accuracy: 0.2500
# Epoch 16/50
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.2692 - val_loss: 0.0000e+00 - val_accuracy: 0.2500
# Epoch 17/50
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0000e+00 - accuracy: 0.2692 - val_loss: 0.0000e+00 - val_accuracy: 0.2500
# Epoch 18/50
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0000e+00 - accuracy: 0.2692 - val_loss: 0.0000e+00 - val_accuracy: 0.2500
# Epoch 19/50
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0000e+00 - accuracy: 0.2692 - val_loss: 0.0000e+00 - val_accuracy: 0.2500
# Epoch 20/50
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0000e+00 - accuracy: 0.2692 - val_loss: 0.0000e+00 - val_accuracy: 0.2500
# Epoch 21/50
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0000e+00 - accuracy: 0.2692 - val_loss: 0.0000e+00 - val_accuracy: 0.2500
# Epoch 22/50
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0000e+00 - accuracy: 0.2692 - val_loss: 0.0000e+00 - val_accuracy: 0.2500
# Epoch 23/50
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0000e+00 - accuracy: 0.2692 - val_loss: 0.0000e+00 - val_accuracy: 0.2500
# Epoch 24/50
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0000e+00 - accuracy: 0.2692 - val_loss: 0.0000e+00 - val_accuracy: 0.2500
# Epoch 25/50
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0000e+00 - accuracy: 0.2692 - val_loss: 0.0000e+00 - val_accuracy: 0.2500
# Epoch 26/50
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0000e+00 - accuracy: 0.2692 - val_loss: 0.0000e+00 - val_accuracy: 0.2500
# Epoch 27/50
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0000e+00 - accuracy: 0.2692 - val_loss: 0.0000e+00 - val_accuracy: 0.2500
# Epoch 28/50
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0000e+00 - accuracy: 0.2692 - val_loss: 0.0000e+00 - val_accuracy: 0.2500
# Epoch 29/50
#  1/15 [=>............................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.2734
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/dh/nfwywq5x6vj6wb3fkdkwkg000000gn/T/ipykernel_13072/979002258.py in <module>
#       7     val_features = scaler.transform(val_features.reshape(-1, val_features.shape[-1])).reshape(val_features.shape)
#       8     model=cnnmodel()
# ----> 9     model.fit(train_features,train_labels,epochs=50,batch_size=128,validation_data=(val_features,val_labels))
#      10     accuracy.append(model.evaluate(val_features,val_labels)[1])
#
# ~/opt/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1654                             logs = tmp_logs
#    1655                             end_step = step + data_handler.step_increment
# -> 1656                             callbacks.on_train_batch_end(end_step, logs)
#    1657                             if self.stop_training:
#    1658                                 break
#
# ~/opt/anaconda3/lib/python3.9/site-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     474         """
#     475         if self._should_call_train_batch_hooks:
# --> 476             self._call_batch_hook(ModeKeys.TRAIN, "end", batch, logs=logs)
#     477
#     478     def on_test_batch_begin(self, batch, logs=None):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     321             self._call_batch_begin_hook(mode, batch, logs)
#     322         elif hook == "end":
# --> 323             self._call_batch_end_hook(mode, batch, logs)
#     324         else:
#     325             raise ValueError(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     344             self._batch_times.append(batch_time)
#     345
# --> 346         self._call_batch_hook_helper(hook_name, batch, logs)
#     347
#     348         if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     392         for callback in self.callbacks:
#     393             hook = getattr(callback, hook_name)
# --> 394             hook(batch, logs)
#     395
#     396         if self._check_timing:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1092
#    1093     def on_train_batch_end(self, batch, logs=None):
# -> 1094         self._batch_update_progbar(batch, logs)
#    1095
#    1096     def on_test_batch_end(self, batch, logs=None):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1168         if self.verbose == 1:
#    1169             # Only block async when verbose = 1.
# -> 1170             logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1171             self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1172
#
# ~/opt/anaconda3/lib/python3.9/site-packages/keras/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     663         return t.item() if np.ndim(t) == 0 else t
#     664
# --> 665     return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     666
#     667
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     915
#     916   return pack_sequence_as(
# --> 917       structure[0], [func(*x) for x in entries],
#     918       expand_composites=expand_composites)
#     919
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     915
#     916   return pack_sequence_as(
# --> 917       structure[0], [func(*x) for x in entries],
#     918       expand_composites=expand_composites)
#     919
#
# ~/opt/anaconda3/lib/python3.9/site-packages/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     656         # Don't turn ragged or sparse tensors to NumPy.
#     657         if isinstance(t, tf.Tensor):
# --> 658             t = t.numpy()
#     659         # Strings, ragged and sparse tensors don't have .item(). Return them
#     660         # as-is.
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1153     """
#    1154     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1155     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1156     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1157
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1119   def _numpy(self):
#    1120     try:
# -> 1121       return self._numpy_internal()
#    1122     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1123       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:
